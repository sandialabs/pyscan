# %%
from pyscan.drivers.thorlabs.thorlabsct1p import ThorlabsCT1P

# %%
ct1p = ThorlabsCT1P()

# %%
ct1p.position
# Out:
# 67.97387615588855

# %%
ct1p.voltage
# Out:
# 65.10315737995538

# %%
ct1p.close()
