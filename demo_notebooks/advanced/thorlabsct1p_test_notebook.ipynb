# %%
from pyscan.drivers.thorlabs.thorlabsct1p import ThorlabsCT1P

# %%
ct1p = ThorlabsCT1P()

# %%
ct1p.polling_duration
# Out:
# 100

# %%
ct1p.front_panel_can_lock
# Out:
# True

# %%
ct1p.front_panel_locked
# Out:
# False

# %% [markdown]
# front_panel_locked: False

# %%
ct1p.front_panel_locked = True

# %%
ct1p.front_panel_locked
# Out:
# True

# %%
ct1p.front_panel_locked = False

# %%
ct1p.front_panel_locked
# Out:
# False

# %%
ct1p.position_control_mode
# Out:
# 2

# %% [markdown]
# position_control_mode: 1: open loop mode

# %%
ct1p.position_control_mode = 2

# %%
ct1p.position_control_mode
# Out:
# 2

# %%
# ct1p.position_control_mode = 1

# %%
# ct1p.position_control_mode
# Out:
# 1

# %%
ct1p.position
# Out:
# 67.61375774407178

# %% [markdown]
# position: 67.61070589312418

# %%
ct1p.voltage
# Out:
# 61.380322156676954

# %% [markdown]
# voltage: 65.10315737995538

# %%
ct1p.position = 70

# %%
ct1p.position
# Out:
# 70.00640888698996

# %% [markdown]
# takes upwards of 10s to stabilize at target

# %%
ct1p.voltage
# Out:
# 61.40783079133172

# %%
ct1p.voltage = 50.

# %%
ct1p.voltage
# Out:
# 61.77002781428615

# %%
ct1p.close()
