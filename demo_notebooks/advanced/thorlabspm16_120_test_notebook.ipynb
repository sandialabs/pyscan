# %%
import pyscan as ps

# %%
pm16_120 = ps.ThorlabsPM16_120()

# %%
pm16_120.wavelength
# Out:
# 532.5

# %% [markdown]
# wavelength: 532.5

# %%
pm16_120.power
# Out:
# 8.4334438e-08

# %%
pm16_120.wavelength = 500

# %%
pm16_120.wavelength
# Out:
# 500

# %%
pm16_120.power
# Out:
# 9.1361414e-08

# %%
pm16_120.wavelength = 532.5

# %%
pm16_120.wavelength
# Out:
# 532.5

# %%
pm16_120.power
# Out:
# 8.4312333e-08

# %%
pm16_120.device_count
# Out:
# 1

# %%
pm16_120.calibration_message
# Out:
# '3-DEC-2025'

# %%
pm16_120.device_list_resource_names
# Out:
# ['USB0::0x1313::0x807B::251203529::INSTR']

# %%
pm16_120.power_auto_range
# Out:
# True

# %% [markdown]
# power_auto_range: True

# %%
pm16_120.power_auto_range = False

# %%
pm16_120.power_auto_range
# Out:
# False

# %%
pm16_120.power_auto_range = True

# %%
pm16_120.power_auto_range
# Out:
# True

# %%
pm16_120.power_unit
# Out:
# 'Watt'

# %% [markdown]
# power_unit: 'Watt'

# %%
pm16_120.power_unit = 'dbm'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pm16_120.power_unit = 'dbm'
#
# File C:\snl\pyscan\pyscan\drivers\thorlabs\thorlabspm16_120.py:185, in ThorlabsPM16_120.power_unit(self, power_unit)
#     180 @power_unit.setter
#     181 def power_unit(self, power_unit):
#     182     '''
#     183     Set power_unit to \'Watt\' or \'dBm\'
#     184     '''
# --> 185     self.set_power_unit(power_unit)
#     186     self._power_unit = power_unit
#
# File C:\snl\pyscan\pyscan\drivers\thorlabs\thorlabspm16_120.py:167, in ThorlabsPM16_120.set_power_unit(self, power_unit)
#     165         power_unit_int = 1
#     166     case _:
# --> 167         raise RuntimeError("power unit must be \'Watt\' or \'dBm\'")
#     168 self.tlPM.setPowerUnit(c_int16(power_unit_int), TLPM_DEFAULT_CHANNEL)
#
# RuntimeError: power unit must be 'Watt' or 'dBm'

# %%
pm16_120.power_unit
# Out:
# 'Watt'

# %%
pm16_120.power_unit = 'dBm'

# %%
pm16_120.power_unit
# Out:
# 'dBm'

# %%
pm16_120.power
# Out:
# -40.730156

# %%
pm16_120.power_unit = 'Watt'

# %%
pm16_120.power_unit
# Out:
# 'Watt'

# %%
pm16_120.power
# Out:
# 8.4628695e-08

# %%
pm16_120.close()
