# %%
from pyscan.drivers.thorlabs.thorlabskim101 import ThorlabsKIM101
from pyscan.drivers.thorlabs.kinesis.definitions.structures import KIM_DriveOPParameters

# %%
kim101 = ThorlabsKIM101()

# %%
kim101.position_1
# Out:
# -1900

# %% [markdown]
# position_1: 0

# %%
# kim101.enable_control()

# %%
# kim101.enable_channel(1)

# %%
kim101.position_1 = 100

# %%
kim101.position_1
# Out:
# 100

# %%
kim101.position_1 = 0

# %%
kim101.position_1
# Out:
# 0

# %%
kim101.position_2
# Out:
# 644

# %% [markdown]
# position_2: 644

# %%
kim101.position_3
# Out:
# 4237

# %% [markdown]
# position_3: 4237

# %%
kim101.position_4
# Out:
# 0

# %% [markdown]
# position_4: 0

# %% [markdown]
# OPParameters

# %%
kim_drive_op_parameters_1 = kim101.get_DriveOPParameters(1)

# %%
kim_drive_op_parameters_1
# Out:
# KIM_DriveOPPParameters_Tuple(max_voltage=c_short(110), step_rate=c_long(500), step_acceleration=c_long(10000))

# %% [markdown]
# (110, 500, 10000)

# %%
kim101.set_DriveOPParameters(1, 100, 400, 9000)

# %%
kim_drive_op_parameters_1 = kim101.get_DriveOPParameters(1)

# %%
kim_drive_op_parameters_1
# Out:
# KIM_DriveOPPParameters_Tuple(max_voltage=c_short(100), step_rate=c_long(400), step_acceleration=c_long(9000))

# %%
kim101.set_DriveOPParameters(1, 110, 500, 10000)

# %%
kim_drive_op_parameters_1 = kim101.get_DriveOPParameters(1)

# %%
kim_drive_op_parameters_1
# Out:
# KIM_DriveOPPParameters_Tuple(max_voltage=c_short(110), step_rate=c_long(500), step_acceleration=c_long(10000))

# %%
# kim_drive_op_parameters_struct_1 = kim101.get_DriveOPParametersStruct(1)

# %%
# kim_drive_op_parameters_struct_1

# %%
# kim_drive_op_parameters_struct_1._maxVoltage
# Out:
# 110

# %%
# kim_drive_op_parameters_struct_1._stepRate
# Out:
# 655360000

# %%
# kim_drive_op_parameters_struct_1._stepAcceleration
# Out:
# 0

# %% [markdown]
# (110, 655360000, 0)

# %%
# op = KIM_DriveOPParameters(100, 400, 9000)

# %%
# kim101.set_DriveOPParametersStruct(1, op)

# %%
# kim_drive_op_parameters_struct_1 = kim101.get_DriveOPParametersStruct(1)

# %%
# kim_drive_op_parameters_struct_1
# Out:
# KIM_DriveOPPParameters_Tuple(max_voltage=c_short(100), step_rate=c_long(400), step_acceleration=c_long(9000))

# %%
# op = KIM_DriveOPParameters(110, 500, 10000)

# %%
# kim101.set_DriveOPParametersStruct(1, op)

# %%
# kim_drive_op_parameters_struct_1 = kim101.get_DriveOPParametersStruct(1)

# %%
# kim_drive_op_parameters_struct_1
# Out:
# KIM_DriveOPPParameters_Tuple(max_voltage=c_short(110), step_rate=c_long(500), step_acceleration=c_long(10000))

# %%
kim101.close()
