# %%
from pyscan.drivers.thorlabs.thorlabskim101 import ThorlabsKIM101

# %%
kim101 = ThorlabsKIM101()

# %%
kim101.position_1
# Out:
# 0

# %%
kim101.position_2
# Out:
# 644

# %%
kim101.position_3
# Out:
# 4237

# %%
kim101.position_4
# Out:
# 0

# %%
kim101.close()
