# %%
import h5py
from os.path import join

from laser_fiber_align_measure_functions import append_measure_opt
from laser_fiber_align_plots import input_separate_output_init, input_separate_output_plot

# %%
backup_dirpath = r'C:\Users\djbasil\Documents\NV\quantumdefects_Backup\qd3\backup'
backup_fname = '20260814T173957.hdf5'

# %%
f = h5py.File(join(backup_dirpath, backup_fname), 'r')

# %%
list(f.keys())
# Out:
# ['iteration',
#  'power_ga',
#  'power_pre_ga',
#  'voltage_x1_ga',
#  'voltage_x2_ga',
#  'voltage_y1_ga',
#  'voltage_y2_ga',
#  'x1_voltage',
#  'x2_voltage',
#  'y1_voltage',
#  'y2_voltage']

# %%
# x1_opt, y1_opt, x2_opt, y2_opt, power_opt \
#     = append_measure_opt(f['voltage_x1_ga'], f['voltage_y1_ga'],
#                          f['voltage_x2_ga'], f['voltage_y2_ga'],
#                          f['power_ga'])

# %%
x1_opt, y1_opt, x2_opt, y2_opt, power_opt \
    = append_measure_opt(f['voltage_x1_ga'], f['voltage_y1_ga'],
                         f['voltage_x2_ga'], f['voltage_y2_ga'],
                         f['power_ga'])

# %%
fig, axs = input_separate_output_init()
input_separate_output_plot(axs,
                           x1_opt, y1_opt,
                           x2_opt, y2_opt,
                           power_opt)
