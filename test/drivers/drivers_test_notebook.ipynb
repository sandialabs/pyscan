# %%
# %load_ext autoreload
# %autoreload 2

import pyscan as ps
from drivers_test_unit import test_driver
# Out:
# Could not load Keysight SD1
# Could not load Keysight SD1
# pylablib not found, AttocubeANC350 not loaded
# Basler Camera software not found, BaserCamera not loaded
# Helios Camera not installed
# msl not installed, Thorlabs BSC203 driver not loaded
# seabreeze module not found, Ocean Optics not imported
# Failed to load spinapi library.
# spinapi is not installed, PulseBlaster driver not loaded.
# Thorlabs Kinesis not found, ThorlabsBSC203 not loaded
# Thorlabs Kinesis not found, ThorlabsBPC303 not loaded
# Thorlabs Kinesis not found, ThorlabsMFF101 not loaded

# %%
from pyvisa import ResourceManager, VisaIOError

# %%
rm = ResourceManager()

rs = rm.list_resources()
# print(rs)
for r in rs:
    res = rm.open_resource(r)
    try:       
        print(r, res.query('*IDN?'))
    except VisaIOError:
        pass
# Out:
# USB0::0x0957::0x2C07::MY57802596::INSTR Agilent Technologies,33522B,MY57802596,4.00-1.19-2.00-58-00
#
# ASRL3::INSTR Keithley Instruments Inc.,Model 2260B-80-27,1403238,01.72.20150702
#
# GPIB0::5::INSTR Stanford_Research_Systems,SR830,s/n86813,ver1.07
#
# GPIB0::8::INSTR Stanford Research Systems,SR470,s/n1069,ver0.14
#
# GPIB0::16::INSTR StanfordResearchSystems,SR620,06481,1.48

# %%
# Jasmine suggests that this may hide a bug in certain drivers where reassigning an instrument connection variable
# will not close the previous connection. This may be an issue we need to test for so that reconnecting is reliable.
# Drivers with this issue may need an additional clause "__close__" to resolve reconnecting issues.
try:
    del srs830
except: 
    pass

srs830 = ps.Stanford830('GPIB0::5::INSTR')

# %%
'''
If a device is failing test cases for a particular property try the following solutions first:

1. Make sure there are no typos, abnormalities, or other mismatches in formatting in the add_device_property section
for the given property.

2. If the instrument's documentation notes that property has dependencies, create a black_list_for_testing attribute
of type list in the driver init and include the .
For the Stanford830 it looks like this: self.black_list_for_testing = ['_input_configuration', "_time_constant"]

3. Make sure that all the properties being added to the device are also updated
For the Standford830 it operates like this: 
    def __init__(self, instrument)
        self.initialize_properties()
        self.update_properties()

    def update_properties(self):
        self.phase
        self.*all other added properties*

If properties are added but not updated in this way it will not pass the drivers test unit.

These are the most common problems I encountered when testing for the Stanford830.    
'''

test_driver(srs830)
# Out:
# Initial state for the Stanford830 was: [('phase', 180.0), ('reference_source', 'external'), ('frequency', 102000.0), ('reference_slope', 'sine zero'), ('harmonic', 1), ('instrument_amplitude', 4.996), ('input_configuration', 'A-B'), ('input_ground', 'AC'), ('input_coupling', 'AC'), ('input_line_filter', 'none'), ('sensitivity', 2e-09), ('reserve_mode', 'high'), ('time_constant', 30), ('filter_slope', 6), ('synchronous_filter', 'off'), ('sample_rate', 0.0625), ('end_buffer_mode', 'one shot'), ('trigger_mode', 'off')]
# These blacklisted settings and their corresponding values were not reset:  [('_input_configuration', 'A-B'), ('_time_constant', 30)]
# Reset state for the Stanford830 was: [('phase', 180.0), ('reference_source', 'external'), ('frequency', 102000.0), ('reference_slope', 'sine zero'), ('harmonic', 1), ('instrument_amplitude', 4.996), ('input_configuration', 'A-B'), ('input_ground', 'AC'), ('input_coupling', 'AC'), ('input_line_filter', 'none'), ('sensitivity', 2e-09), ('reserve_mode', 'high'), ('time_constant', 30), ('filter_slope', 6), ('synchronous_filter', 'off'), ('sample_rate', 0.0625), ('end_buffer_mode', 'one shot'), ('trigger_mode', 'off')]
# Beginning tests for:  Stanford830
# 4 range properties found and tested out of 18 total settings found.
# 0 values properties found and tested out of 18 total settings found.
# 10 indexed values properties found and tested out of 18 total settings found.
# 2 dict values properties found and tested out of 18 total settings found.
# 2 blacklisted settings not testing (likely due to interdependencies not suitable for automated testing)
# 16 properties tested out of 18 total settings.
# Settings restored to: [('phase', 180.0), ('reference_source', 'external'), ('frequency', 102000.0), ('reference_slope', 'sine zero'), ('harmonic', 1), ('instrument_amplitude', 4.996), ('input_configuration', 'A-B'), ('input_ground', 'AC'), ('input_coupling', 'AC'), ('input_line_filter', 'none'), ('sensitivity', 2e-09), ('reserve_mode', 'high'), ('time_constant', 30), ('filter_slope', 6), ('synchronous_filter', 'off'), ('sample_rate', 0.0625), ('end_buffer_mode', 'one shot'), ('trigger_mode', 'off')]
# Tests passed, instrument Stanford830 should be ready to go.

# %%
srs830.input_configuration = 'A-B'
# Out:
# ISRC 1

# %%
srs830.input_configuration
# Out:
# 'A-B'

# %%
srs830.input_configuration?
# Out:
# Type:        property
# String form: <property object at 0x00000189DEF97420>
# Docstring:
# input_configuration : int
# indexed_values: ['A', 'A-B', 'Ie6', 'Ie8']

# %%
try:
    del keithley
except: 
    pass
keithley = ps.Keithley2260B('ASRL3::INSTR')

# %%
test_driver(keithley)
# Out:
# Initial state for the Keithley2260B was: [('output_on_delay', 0.0), ('output_off_delay', 0.0), ('output_mode', 'CVHS'), ('output', 'Off'), ('output_trigger_state', 'Off'), ('smoothing', 'low'), ('current', 0.0), ('current_trigger_amplitude', 0.0), ('over_current_level', 2.7), ('current_protection_state', 'Off'), ('current_rising_slew_rate', 0.01), ('current_falling_slew_rate', 0.01), ('resistance', 0.0), ('voltage', 0.0), ('voltage_trigger_amplitude', 0.0), ('over_voltage_level', 8.0), ('voltage_rising_slew_rate', 0.1), ('voltage_falling_slew_rate', 0.1), ('transient_trigger_source', 'BUS'), ('output_trigger_source', 'IMM')]
# These blacklisted settings and their corresponding values were not reset:  [('_output', 'Off'), ('_current', 0.0), ('_voltage', 0.0)]
# Reset state for the Keithley2260B was: [('output_on_delay', 0.0), ('output_off_delay', 0.0), ('output_mode', 'CVHS'), ('output', 'Off'), ('output_trigger_state', 'Off'), ('smoothing', 'low'), ('current', 0.0), ('current_trigger_amplitude', 0.0), ('over_current_level', 2.7), ('current_protection_state', 'Off'), ('current_rising_slew_rate', 0.01), ('current_falling_slew_rate', 0.01), ('resistance', 0.0), ('voltage', 0.0), ('voltage_trigger_amplitude', 0.0), ('over_voltage_level', 8.0), ('voltage_rising_slew_rate', 0.1), ('voltage_falling_slew_rate', 0.1), ('transient_trigger_source', 'BUS'), ('output_trigger_source', 'IMM')]
# Beginning tests for:  Keithley2260B
# 11 range properties found and tested out of 20 total settings found.
# 2 values properties found and tested out of 20 total settings found.
# 2 indexed values properties found and tested out of 20 total settings found.
# 2 dict values properties found and tested out of 20 total settings found.
# 3 blacklisted settings not testing (likely due to interdependencies not suitable for automated testing)
# 17 properties tested out of 20 total settings.
# Settings restored to: [('output_on_delay', 0.0), ('output_off_delay', 0.0), ('output_mode', 'CVHS'), ('output', 'Off'), ('output_trigger_state', 'Off'), ('smoothing', 'low'), ('current', 0.0), ('current_trigger_amplitude', 0.0), ('over_current_level', 2.7), ('current_protection_state', 'Off'), ('current_rising_slew_rate', 0.01), ('current_falling_slew_rate', 0.01), ('resistance', 0.0), ('voltage', 0.0), ('voltage_trigger_amplitude', 0.0), ('over_voltage_level', 8.0), ('voltage_rising_slew_rate', 0.1), ('voltage_falling_slew_rate', 0.1), ('transient_trigger_source', 'BUS'), ('output_trigger_source', 'IMM')]
# Tests passed, instrument Keithley2260B should be ready to go.
