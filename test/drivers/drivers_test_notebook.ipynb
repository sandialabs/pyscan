# %%
# %load_ext autoreload
# %autoreload 2

import pyscan as ps
import pytest
from drivers_test_unit import test_driver
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
try:
    del srs830
except: 
    pass

srs830 = ps.Stanford830('GPIB0::5::INSTR')

# %%
test_driver(srs830)
# Out:
# Beginning tests for:  Stanford830
# FMOD 0
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_driver(srs830)
#
# File c:\Users\rsbrost\Documents\pyscan\test\drivers\drivers_test_unit.py:250, in test_driver(device, expected_attributes, expected_values)
#     247     if expected_values is not None:
#     248         check_attribute_values(device, expected_attributes, expected_values)
# --> 250 check_properties(device)
#     252 print("Tests passed, instrument {} should be ready to go.".format(device.__class__.__name__))
#
# File c:\Users\rsbrost\Documents\pyscan\test\drivers\drivers_test_unit.py:222, in check_properties(test_instrument)
#     220     idx_vals_counter += 1
#     221     # idx_vals_idx.append(idx_vals_counter)
# --> 222     check_indexed_property(test_instrument, name)
#     223 elif 'dict_values' in test_instrument[name].keys():
# ...
