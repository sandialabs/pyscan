# %%
import pyscan as ps
from pyscan.drivers.thorlabs.thorlabspm16_120 import ThorlabsPM16_120

# %%
pm16120 = ThorlabsPM16_120()

# %%
pm16120.measure_power()
# Out:
# 8.4870123e-08

# %%
pm16120.disconnect()
